# %%
! pip install gpytorch

import os
from google.colab import drive
drive.mount('/content/drive')
project_path = '/content/drive/My Drive/ML for RES'
os.chdir(project_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import torch, gpytorch, os, time, pickle
from sklearn.preprocessing import StandardScaler
import numpy as np
import seaborn as sns

from gpytorch.models import ApproximateGP
from gpytorch.variational import (
    CholeskyVariationalDistribution,
    VariationalStrategy,
    LMCVariationalStrategy,
    MultitaskVariationalStrategy
)
from gpytorch.mlls.variational_elbo import VariationalELBO
from gpytorch.kernels import RBFKernel, ScaleKernel, MultitaskKernel
from gpytorch.likelihoods import MultitaskGaussianLikelihood, GaussianLikelihood
from torch.utils.data import TensorDataset, DataLoader


from utils import load_and_merge_weather_data, load_supply_data, load_installed_cap_data, get_time_intersection, concat_tables, add_hour_column, add_year_column, df_to_tensor, perform_gridsearch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'using device: {device}')

RANDOM_SEED = 42

data_folder = 'data'
weather_data_fpaths = [os.path.join(data_folder, weather_file)for weather_file in ['Weather_Data_Germany.csv', 'Weather_Data_Germany_2022.csv']]
supply_data_fpath = os.path.join(data_folder, 'Realised_Supply_Germany.csv')
cap_data_fpath = os.path.join(data_folder, 'Installed_Capacity_Germany.csv')
# Out:
# using device: cuda

# %% [markdown]
# # Loading the Data and Preprocessing

# %%
weather_df = load_and_merge_weather_data(weather_data_fpaths)

weather_df.iloc[[0, 1, 23, 24, 25, -2, -1]]
# Out:
#                            time         cdir            z            msl  \
# 0     2019-01-01 00:00:00+00:00        0.000  3360.296561  103009.967750
# 1     2019-01-01 01:00:00+00:00        0.000  3360.296561  102964.489612
# 23    2019-01-01 23:00:00+00:00  3066853.275  3360.296561  102310.656087
# 24    2019-01-02 00:00:00+00:00        0.000  3360.296561  102431.760900
# 25    2019-01-02 01:00:00+00:00        0.000  3360.296561  102462.246775
# 35062 2022-12-31 22:00:00+00:00  3010416.425  3360.300465  101413.335688
# 35063 2022-12-31 23:00:00+00:00  3010416.425  3360.300465  101444.050062
#
#                blh       tcc       u10       v10         t2m           ssr  \
# 0       507.635043  0.966562  3.867164  1.065368  278.216013  0.000000e+00
# 1       544.627164  0.959348  4.092345  1.116217  278.310794  0.000000e+00
# 23     1282.185074  0.628171  5.543300 -4.233978  276.084614  1.617137e+06
# 24     1190.333533  0.660718  5.078227 -4.134211  275.615555  0.000000e+00
# 25     1234.541036  0.598510  4.837781 -4.484831  275.565373  0.000000e+00
# 35062   855.964935  0.824257  4.053605  4.901148  284.452551  2.210629e+06
# 35063   844.058690  0.809066  4.008353  4.860213  284.285022  2.210669e+06
#
#                tsr          sund            tp       fsr      u100      v100
# 0            0.000      0.000000  0.000000e+00  0.741971  6.545994  1.122055
# 1            0.000      0.000000  3.803349e-05  0.742205  6.838839  1.241379
# 23     3531474.625   9901.251962  1.907228e-03  0.742104  8.717265 -6.877415
# 24           0.000     -0.007812  7.450581e-09  0.741824  8.010838 -6.809227
# 25           0.000     -0.007812  1.602382e-04  0.742285  7.592956 -7.328369
# 35062  4074921.825  11443.273025  5.087158e-03  0.745430  7.320207  8.137603
# 35063  4074921.825  11443.273025  5.100906e-03  0.745408  7.251386  8.022535

# %%
df_numerical = weather_df.drop(columns=['time'])

corr_matrix = df_numerical.corr()
mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, mask=mask, annot=True, fmt=".2f", cmap='coolwarm', square=True,
            cbar_kws={"shrink": .8}, linewidths=0.5)
plt.title('Feature Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
supply_hourly = load_supply_data(supply_data_fpath)
supply_hourly
# Out:
#                            time  solar_supply_sum  solar_supply_mean
# 0     2019-01-01 00:00:00+00:00               0.0                0.0
# 1     2019-01-01 01:00:00+00:00               0.0                0.0
# 2     2019-01-01 02:00:00+00:00               0.0                0.0
# 3     2019-01-01 03:00:00+00:00               0.0                0.0
# 4     2019-01-01 04:00:00+00:00               0.0                0.0
# ...                         ...               ...                ...
# 35055 2022-12-31 19:00:00+00:00               0.0                0.0
# 35056 2022-12-31 20:00:00+00:00               0.0                0.0
# 35057 2022-12-31 21:00:00+00:00               0.0                0.0
# 35058 2022-12-31 22:00:00+00:00               0.0                0.0
# 35059 2022-12-31 23:00:00+00:00               0.0                0.0
#
# [35060 rows x 3 columns]

# %%
random_date = np.random.choice(supply_hourly['time'].dt.date)
mask = supply_hourly['time'].dt.date == random_date
df_day = supply_hourly[mask].sort_values('time')

plt.figure(figsize=(8, 3))
plt.plot(df_day['time'], df_day['solar_supply_sum'], color='green', linewidth=2)
plt.title(f'Solar Supply on {random_date.strftime("%-d.%-m.%Y")}', fontsize=12)
plt.xlabel('Time (Hourly)', fontsize=10)
plt.ylabel('Solar Supply (Sum per hour)', fontsize=10)

# Format x-axis for hours
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

# Grid and layout
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df_sorted = supply_hourly.sort_values('time', ascending=True)

# Create the plot
plt.figure(figsize=(11, 6))
plt.plot(df_sorted['time'], df_sorted['solar_supply_sum'], color='green', linewidth=0.5)

# Set axis labels
plt.xlabel('Time', fontsize=12)
plt.ylabel('Solar Supply (Sum per hour)', fontsize=12)
plt.title('Hourly Solar Supply Over Time', fontsize=14)

# Format x-axis ticks
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%Y'))

plt.grid(True, which='major', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
capacity_df = load_installed_cap_data(cap_data_fpath)
# capacity_df
print(capacity_df.iloc[[0, -1]])

plt.figure()
plt.plot(capacity_df.index, capacity_df.values)
plt.xlabel('Time')
plt.ylabel('Photovoltaic Capacity (MW)')
plt.title('Hourly Interpolated Installed Photovoltaic Capacity')
plt.xticks(rotation=-45)
plt.tight_layout()
plt.show()
# Out:
# 2019-01-01 00:00:00+00:00    44036.0
# 2023-01-01 00:00:00+00:00    57744.0
# Freq: 35064h, Name: Photovoltaic [MW], dtype: float64

# %% [markdown]
# ### Combine the tree tables based on the intersection of dates present
# Only use the data points from dates which are included in all datasets

# %%
print(f"Supply data ranges from {supply_hourly['time'].min()} to {supply_hourly['time'].max()}")
print(f"Weather data ranges from {weather_df['time'].min()} to {weather_df['time'].max()}")
print(f"Installed capacity ranges from {capacity_df.index.min()} to {capacity_df.index.max()}")
common_time_idx = get_time_intersection(weather_df, supply_hourly, capacity_df)
# Out:
# Supply data ranges from 2019-01-01 00:00:00+00:00 to 2022-12-31 23:00:00+00:00
# Weather data ranges from 2019-01-01 00:00:00+00:00 to 2022-12-31 23:00:00+00:00
# Installed capacity ranges from 2019-01-01 00:00:00+00:00 to 2023-01-01 00:00:00+00:00
# Common window: 2019-01-01 00:00:00+00:00 - 2022-12-31 23:00:00+00:00

# %%
target_col = 'solar_supply_sum'  # or 'solar_supply_mean'
full_data = concat_tables(common_time_idx, supply_hourly, weather_df, capacity_df, target_col)

# %%
add_hour_column(full_data)
add_year_column(full_data)

# %%
plt.figure(figsize=(10, 6))
plt.subplots_adjust(hspace=0.5)

# Plot of yearly time encoding
plt.subplot(2,1,1)
plt.plot(full_data.index, full_data['day_of_year_sin'], label="sin(day of year)")
plt.plot(full_data.index, full_data['day_of_year_cos'], label="cos(day of year)")

plt.title('Yearly Time Encoding')
plt.xlabel('Date')
plt.legend(loc='upper right')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True, which='major', linestyle='--', alpha=0.5)
ax.xaxis.set_major_formatter(DateFormatter('%m.%Y'))
#plt.xticks(rotation=-45)

# Plot of daily time encoding
plt.subplot(2,1,2)
plt.plot(full_data.index[0:24*3], full_data['hour_sin'][0:24*3], label="sin(hour of day)")
plt.plot(full_data.index[0:24*3], full_data['hour_cos'][0:24*3], label="cos(hour of day)")

plt.title('Daily Time Encoding')
plt.xlabel('Date')
plt.legend(loc='upper right')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.DayLocator())
ax.xaxis.set_major_formatter(DateFormatter('%d.%m.%Y %H:00'))
plt.grid(True, which='major', linestyle='--', alpha=0.5)
#plt.xticks(rotation=0)

plt.show()

# %%
data_cols = full_data.columns

full_data
# Out:
#                            solar_supply         cdir            z  \
# 2019-01-01 00:00:00+00:00           0.0        0.000  3360.296561
# 2019-01-01 01:00:00+00:00           0.0        0.000  3360.296561
# 2019-01-01 02:00:00+00:00           0.0        0.000  3360.296561
# 2019-01-01 03:00:00+00:00           0.0        0.000  3360.296561
# 2019-01-01 04:00:00+00:00           0.0        0.000  3360.296561
# ...                                 ...          ...          ...
# 2022-12-31 19:00:00+00:00           0.0  3010497.350  3360.300465
# 2022-12-31 20:00:00+00:00           0.0  3010497.350  3360.300465
# 2022-12-31 21:00:00+00:00           0.0  3010416.425  3360.300465
# 2022-12-31 22:00:00+00:00           0.0  3010416.425  3360.300465
# 2022-12-31 23:00:00+00:00           0.0  3010416.425  3360.300465
#
#                                      msl         blh       tcc       u10  \
# 2019-01-01 00:00:00+00:00  103009.967750  507.635043  0.966562  3.867164
# 2019-01-01 01:00:00+00:00  102964.489612  544.627164  0.959348  4.092345
# 2019-01-01 02:00:00+00:00  102908.208325  575.103757  0.966846  4.320050
# 2019-01-01 03:00:00+00:00  102827.034387  612.314609  0.979125  4.638074
# 2019-01-01 04:00:00+00:00  102725.913987  660.112603  0.981526  4.980449
# ...                                  ...         ...       ...       ...
# 2022-12-31 19:00:00+00:00  101343.109762  772.449598  0.894857  3.526524
# 2022-12-31 20:00:00+00:00  101364.929637  835.039963  0.864447  3.794407
# 2022-12-31 21:00:00+00:00  101389.839013  853.389589  0.841012  3.948474
# 2022-12-31 22:00:00+00:00  101413.335688  855.964935  0.824257  4.053605
# 2022-12-31 23:00:00+00:00  101444.050062  844.058690  0.809066  4.008353
#
#                                 v10         t2m           ssr  ...  \
# 2019-01-01 00:00:00+00:00  1.065368  278.216013  0.000000e+00  ...
# 2019-01-01 01:00:00+00:00  1.116217  278.310794  0.000000e+00  ...
# 2019-01-01 02:00:00+00:00  1.223478  278.206292  0.000000e+00  ...
# 2019-01-01 03:00:00+00:00  1.222571  278.140331  0.000000e+00  ...
# 2019-01-01 04:00:00+00:00  1.055763  278.102989  0.000000e+00  ...
# ...                             ...         ...           ...  ...
# 2022-12-31 19:00:00+00:00  4.758480  284.654883  2.210629e+06  ...
# 2022-12-31 20:00:00+00:00  4.867906  284.625625  2.210629e+06  ...
# 2022-12-31 21:00:00+00:00  4.908642  284.563871  2.210629e+06  ...
# 2022-12-31 22:00:00+00:00  4.901148  284.452551  2.210629e+06  ...
# 2022-12-31 23:00:00+00:00  4.860213  284.285022  2.210669e+06  ...
#
#                                    sund        tp       fsr      u100  \
# 2019-01-01 00:00:00+00:00      0.000000  0.000000  0.741971  6.545994
# 2019-01-01 01:00:00+00:00      0.000000  0.000038  0.742205  6.838839
# 2019-01-01 02:00:00+00:00      0.000000  0.000070  0.742254  7.183921
# 2019-01-01 03:00:00+00:00      0.000000  0.000099  0.742272  7.660834
# 2019-01-01 04:00:00+00:00      0.000000  0.000135  0.742255  8.147790
# ...                                 ...       ...       ...       ...
# 2022-12-31 19:00:00+00:00  11443.273025  0.004806  0.745599  6.526197
# 2022-12-31 20:00:00+00:00  11443.273025  0.004993  0.745539  6.902650
# 2022-12-31 21:00:00+00:00  11443.273025  0.005059  0.745457  7.133971
# 2022-12-31 22:00:00+00:00  11443.273025  0.005087  0.745430  7.320207
# 2022-12-31 23:00:00+00:00  11443.273025  0.005101  0.745408  7.251386
#
#                                v100  Installed_Capacity  hour_sin  hour_cos  \
# 2019-01-01 00:00:00+00:00  1.122055        44036.000000  0.000000  1.000000
# 2019-01-01 01:00:00+00:00  1.241379        44036.424429  0.258819  0.965926
# 2019-01-01 02:00:00+00:00  1.428783        44036.848858  0.500000  0.866025
# 2019-01-01 03:00:00+00:00  1.501984        44037.273288  0.707107  0.707107
# 2019-01-01 04:00:00+00:00  1.289936        44037.697717  0.866025  0.500000
# ...                             ...                 ...       ...       ...
# 2022-12-31 19:00:00+00:00  7.935821        57744.000000 -0.965926  0.258819
# 2022-12-31 20:00:00+00:00  8.148097        57744.000000 -0.866025  0.500000
# 2022-12-31 21:00:00+00:00  8.186220        57744.000000 -0.707107  0.707107
# 2022-12-31 22:00:00+00:00  8.137603        57744.000000 -0.500000  0.866025
# 2022-12-31 23:00:00+00:00  8.022535        57744.000000 -0.258819  0.965926
#
#                            day_of_year_sin  day_of_year_cos
# 2019-01-01 00:00:00+00:00         0.000000         1.000000
# 2019-01-01 01:00:00+00:00         0.000000         1.000000
# 2019-01-01 02:00:00+00:00         0.000000         1.000000
# 2019-01-01 03:00:00+00:00         0.000000         1.000000
# 2019-01-01 04:00:00+00:00         0.000000         1.000000
# ...                                    ...              ...
# 2022-12-31 19:00:00+00:00        -0.017213         0.999852
# 2022-12-31 20:00:00+00:00        -0.017213         0.999852
# 2022-12-31 21:00:00+00:00        -0.017213         0.999852
# 2022-12-31 22:00:00+00:00        -0.017213         0.999852
# 2022-12-31 23:00:00+00:00        -0.017213         0.999852
#
# [35064 rows x 21 columns]

# %% [markdown]
# ### Preprocessing
#
# This involves splitting the data into train/test and standadization of each input feature to have a mean $\mu=0$ and a standard deviation $\sigma=1$ based on the train data
#
# Each column of the data needs to be standardized **individually**!
#
# $$\operatorname{Standardization: } z=\frac{x-\mu}{\sigma}$$

# %%
# Identify which columns to scale vs. which ones to keep. -> Keep the time (sin & cos) columns
all_features = full_data.columns.tolist()
target_col   = 'solar_supply'
feature_cols_static = ['hour_sin', 'hour_cos', 'day_of_year_sin', 'day_of_year_cos'] # these go straight into X without scaling
feature_cols_to_scale = [c for c in all_features if (c not in feature_cols_static and c != target_col)]

# test_idx are all datapoints corresponding to the last year
last_year = full_data.index.year.max()
train_idx = full_data.index.year < last_year

# Train feature scalers that standardize the columns
# target_scaler trained on all solar_supply column from the train dataset
target_scaler = StandardScaler().fit(full_data.loc[train_idx, ['solar_supply']])

# feature_scaler on all other columns from the train dataset
feature_scaler = StandardScaler().fit(full_data.loc[train_idx, feature_cols_to_scale])

# Apply them to the full_data
full_data_scaled = full_data.copy()
# Scale the continuous features and leave time features untouched
full_data_scaled.loc[:, feature_cols_to_scale] = feature_scaler.transform(
    full_data_scaled[feature_cols_to_scale]
)
full_data_scaled['solar_supply'] = target_scaler.transform(full_data_scaled[['solar_supply']])

# %% [markdown]
# Create the forecast for a certain horizon

# %%
horizon = 24 # How many hours we want to predict into the future
y_df = pd.concat(
    {f'y+{i}h': full_data_scaled[target_col].shift(-i) for i in range(1, horizon+1)},
    axis=1
).dropna() # Remove the last 24 entries as they contain NaNs

# Ensure only values from the full table are taken for which there are values in the y_df (removes the last 24 entries)
X_df = full_data_scaled.loc[y_df.index]

# Train/test split by year
train_mask = X_df.index.year < last_year
X_train, y_train = X_df.loc[train_mask], y_df.loc[train_mask]
X_test,  y_test  = X_df.loc[~train_mask], y_df.loc[~train_mask]

# Convert data to tensors
X_train, y_train, X_test, y_test = map(
    lambda x: df_to_tensor(x, device), (X_train, y_train, X_test, y_test)
)

dates_train = X_df.loc[train_mask].index
dates_test = X_df.loc[~train_mask].index

# Shapes check
print(f'Train data | X: {X_train.shape} y: {y_train.shape}')  # (n_train, n_features), (n_train, 24)
print(f'Test data  | X: {X_test.shape} y: {y_test.shape}')   # (n_test,  n_features), (n_test,  24)
# Out:
# Train data | X: torch.Size([26304, 21]) y: torch.Size([26304, 24])
# Test data  | X: torch.Size([8736, 21]) y: torch.Size([8736, 24])

# %% [markdown]
# Sanity check: Check whether y_train contains the next 24 hours solar supply from X_train

# %%
i = 206
plt.plot(X_train[i:i+24,0].cpu().numpy(), label="X_train[i:i+24]")
plt.plot(y_train[i].cpu().numpy(), label="y_train[i]")
plt.legend()
plt.show()

# %% [markdown]
# # Model
#
# The exact GP is not suitable as it scales $\mathcal{O}(n^3)$, so we need to use an Approximate GP with a Variational Strategy, e.g. maximizing the Evidence lower-bound (ELBO)

# %%
class GPModel(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, num_tasks, num_latents,
                 mean_module, covar_module):
        """
        inducing_points: Tensor (M, D)
        num_tasks:       # of outputs, here 24
        num_latents:     # of latent GPs to mix (<= num_tasks)
        mean_module:     a gpytorch.means.Mean object, batched [num_latents]
        covar_module:    a gpytorch.kernels.Kernel within ScaleKernel, batched
        """
        # 1) variational distribution for each latent GP
        M = inducing_points.size(0)
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            M, batch_shape=torch.Size([num_latents])
        )
        # 2) single‐task variational strategy, batched
        base_vs = gpytorch.variational.VariationalStrategy(
            self,
            inducing_points.unsqueeze(0).expand(num_latents, M, -1),
            variational_distribution,
            learn_inducing_locations=True
        )
        # 3) mix latents → tasks
        variational_strategy = gpytorch.variational.LMCVariationalStrategy(
            base_vs, num_tasks, num_latents, latent_dim=-1
        )
        super().__init__(variational_strategy)

        # plug in chosen mean & covar modules
        self.mean_module = mean_module
        self.covar_module = covar_module

    def forward(self, x):
        # x: (..., D)
        mean = self.mean_module(x)        # → (num_latents, N)
        covar = self.covar_module(x)      # → (num_latents, N, N)
        return gpytorch.distributions.MultivariateNormal(mean, covar)

# %% [markdown]
# # Parameter Search to find the model that fits the data best

# %% [markdown]
# Define the search space for our grid-search: Number of inducing points, latent dimension, learning rates, epochs, mean kernels and covariance kernels
#
# **First start a coarse search and then a fine one due too computational restrictions**

# %%
inducing_list = [1024, 512]
latents_list  = [12]
lr_list       = [5e-3]
epochs_list   = [250]

# kernel choices (each must accept num_latents → batched module)
kernel_builders = {
    'RBF'        : lambda L: gpytorch.kernels.ScaleKernel(
                         gpytorch.kernels.RBFKernel(batch_shape=torch.Size([L])),
                         batch_shape=[L]),
    'Matern32_nu_2_5'   : lambda L: gpytorch.kernels.ScaleKernel(
                         gpytorch.kernels.MaternKernel(nu=2.5,
                             batch_shape=[L]),
                         batch_shape=[L]),
    'Matern32_nu_2_5+Periodic': lambda L:
        gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel(nu=2.5, batch_shape=[L]), batch_shape=[L])
        + gpytorch.kernels.ScaleKernel(gpytorch.kernels.PeriodicKernel(batch_shape=[L]), batch_shape=[L]),
    #'RBFxPeriodic': lambda L:
    #    gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(batch_shape=torch.Size([L])))
    #    * gpytorch.kernels.ScaleKernel(gpytorch.kernels.PeriodicKernel(batch_shape=[L]),
    #                     batch_shape=[L]),
    #'RBFxPeriodic+Matern_nu_2_5': lambda L: gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(batch_shape=torch.Size([L]))
    #                     * gpytorch.kernels.PeriodicKernel(batch_shape=[L]),bbatch_shape=[L])
    #                    + gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel(nu=2.5, batch_shape=[L]), batch_shape=[L]),
}

# mean choices
mean_builders = {
    'Constant'  : lambda L: gpytorch.means.ConstantMean(batch_shape=torch.Size([L])),
    #'Zero'      : lambda L: gpytorch.means.ZeroMean(batch_shape=[L]),
    #'Linear'    : lambda L: gpytorch.means.LinearMean(input_size=X_train.shape[1],batch_shape=[L]),
}

# %%
best_config = perform_gridsearch(kernel_builders, mean_builders, inducing_list, latents_list, epochs_list, lr_list, device, RANDOM_SEED, X_train, y_train, GPModel)

print('Best configuration:')
for k,v in best_config.items():
    print(f'  {k:12s} : {v}')

with open("best_config_coarse_run.pkl", "wb") as f:
    pickle.dump(best_config, f)
# Out:
# Fold 3 | Epoch 250/250:   0%|                                                                                                                            | 0/3 [10:08:43<?, ?it/s, rmse=0.224]
#   1/6 in 36523.79s | GP(Constant, RBF) | num_inducing=1024, num_latents=12, lr=0.0050, epochs=250 → RMSE=0.2250
# Fold 3 | Epoch 250/250:   0%|                                                                                                                       | 0/3 [1:58:25<?, ?it/s, rmse=0.206]
#   2/6 in 7105.52s | GP(Constant, RBF) | num_inducing=512, num_latents=12, lr=0.0050, epochs=250 → RMSE=0.2054
# Fold 3 | Epoch 250/250:   0%|                                                                                                                      | 0/3 [10:29:44<?, ?it/s, rmse=0.221]
#   3/6 in 37784.24s | GP(Constant, Matern32_nu_2_5) | num_inducing=1024, num_latents=12, lr=0.0050, epochs=250 → RMSE=0.2197
# Fold 3 | Epoch 250/250:   0%|                                                                                                                       | 0/3 [2:05:23<?, ?it/s, rmse=0.201]
#   4/6 in 7523.47s | GP(Constant, Matern32_nu_2_5) | num_inducing=512, num_latents=12, lr=0.0050, epochs=250 → RMSE=0.1995
# [5/6] Matern32_nu_2_5+Periodic-Constant:   0%|                                                                                                                    | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 best_config = perform_gridsearch(kernel_builders, mean_builders, inducing_list, latents_list, epochs_list, lr_list, device, RANDOM_SEED, X_train, y_train, GPModel)
#       3 print('Best configuration:')
#       4 for k,v in best_config.items():
#
# File ~/Desktop/ML for RES/utils.py:335, in perform_gridsearch(kernel_builders, mean_builders, inducing_list, latents_list, epochs_list, lr_list, device, RANDOM_SEED, X_train, y_train, GPModel)
#     333 X_tr, X_val = X_train[tr_idx], X_train[val_idx]
#     334 y_tr, y_val = y_train[tr_idx], y_train[val_idx]
# --> 335 rmse = train_and_eval(
#     336     X_tr, y_tr, X_val, y_val,
#     337     kbuilder, mbuilder,
#     338     num_inducing, num_latents,
#     339     lr, epochs, GPModel, device, fold_i=fold_i, outer_pbar=fold_pbar
#     340 )
#     341 fold_pbar.set_postfix(rmse=rmse)
#     342 rmses.append(rmse)
#
# File ~/Desktop/ML for RES/utils.py:295, in train_and_eval(X_tr, y_tr, X_val, y_val, kernel_builder, mean_builder, num_inducing, num_latents, lr, num_epochs, GPModel, device, fold_i, outer_pbar)
#     293 X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#     294 optimizer.zero_grad()
# --> 295 output = model(X_batch)
#     296 loss = -mll(output, y_batch)
#     297 loss.backward()
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/models/approximate_gp.py:114, in ApproximateGP.__call__(self, inputs, prior, **kwargs)
#     112 if inputs is not None and inputs.dim() == 1:
#     113     inputs = inputs.unsqueeze(-1)
# --> 114 return self.variational_strategy(inputs, prior=prior, **kwargs)
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/lmc_variational_strategy.py:197, in LMCVariationalStrategy.__call__(self, x, prior, task_indices, **kwargs)
#     163 def __call__(
#     164     self, x: Tensor, prior: bool = False, task_indices: Optional[LongTensor] = None, **kwargs
#     165 ) -> Union[MultitaskMultivariateNormal, MultivariateNormal]:
#     166     r"""
#     167     Computes the variational (or prior) distribution
#     168     :math:`q( \mathbf f \mid \mathbf X)` (or :math:`p( \mathbf f \mid \mathbf X)`).
#    (...)    195         or ~gpytorch.distributions.MultivariateNormal (... x N)
#     196     """
# --> 197     latent_dist = self.base_variational_strategy(x, prior=prior, **kwargs)
#     198     num_batch = len(latent_dist.batch_shape)
#     199     latent_dim = num_batch + self.latent_dim
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/variational_strategy.py:272, in VariationalStrategy.__call__(self, x, prior, **kwargs)
#     269         # Mark that we have updated the variational strategy
#     270         self.updated_strategy.fill_(True)
# --> 272 return super().__call__(x, prior=prior, **kwargs)
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/_variational_strategy.py:347, in _VariationalStrategy.__call__(self, x, prior, **kwargs)
#     345 # Get q(f)
#     346 if isinstance(variational_dist_u, MultivariateNormal):
# --> 347     return super().__call__(
#     348         x,
#     349         inducing_points,
#     350         inducing_values=variational_dist_u.mean,
#     351         variational_inducing_covar=variational_dist_u.lazy_covariance_matrix,
#     352         **kwargs,
#     353     )
#     354 elif isinstance(variational_dist_u, Delta):
#     355     return super().__call__(
#     356         x, inducing_points, inducing_values=variational_dist_u.mean, variational_inducing_covar=None, **kwargs
#     357     )
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/module.py:82, in Module.__call__(self, *inputs, **kwargs)
#      81 def __call__(self, *inputs, **kwargs) -> Union[Tensor, Distribution, LinearOperator]:
# ---> 82     outputs = self.forward(*inputs, **kwargs)
#      83     if isinstance(outputs, list):
#      84         return [_validate_module_outputs(output) for output in outputs]
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/variational_strategy.py:197, in VariationalStrategy.forward(self, x, inducing_points, inducing_values, variational_inducing_covar, **kwargs)
#     195 test_mean = full_output.mean[..., num_induc:]
#     196 induc_induc_covar = full_covar[..., :num_induc, :num_induc].add_jitter(self.jitter_val)
# --> 197 induc_data_covar = full_covar[..., :num_induc, num_induc:].to_dense()
#     198 data_data_covar = full_covar[..., num_induc:, num_induc:]
#     200 # Compute interpolation terms
#     201 # K_ZZ^{-1/2} K_ZX
#     202 # K_ZZ^{-1/2} \mu_Z
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/utils/memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:410, in LazyEvaluatedKernelTensor.to_dense(self)
#     408 @cached
#     409 def to_dense(self):
# --> 410     return self.evaluate_kernel().to_dense()
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/utils/memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:25, in recall_grad_state.<locals>.wrapped(self, *args, **kwargs)
#      22 @functools.wraps(method)
#      23 def wrapped(self, *args, **kwargs):
#      24     with torch.set_grad_enabled(self._is_grad_enabled):
# ---> 25         output = method(self, *args, **kwargs)
#      26     return output
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:355, in LazyEvaluatedKernelTensor.evaluate_kernel(self)
#     353     temp_active_dims = self.kernel.active_dims
#     354     self.kernel.active_dims = None
# --> 355     res = self.kernel(
#     356         x1,
#     357         x2,
#     358         diag=False,
#     359         last_dim_is_batch=self.last_dim_is_batch,
#     360         **self.params,
#     361     )
#     362     self.kernel.active_dims = temp_active_dims
#     364 # Check the size of the output
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/kernels/kernel.py:539, in Kernel.__call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     536     res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     537 else:
#     538     res = to_linear_operator(
# --> 539         super(Kernel, self).__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params)
#     540     )
#     541 return res
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/module.py:82, in Module.__call__(self, *inputs, **kwargs)
#      81 def __call__(self, *inputs, **kwargs) -> Union[Tensor, Distribution, LinearOperator]:
# ---> 82     outputs = self.forward(*inputs, **kwargs)
#      83     if isinstance(outputs, list):
#      84         return [_validate_module_outputs(output) for output in outputs]
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/kernels/kernel.py:622, in AdditiveKernel.forward(self, x1, x2, diag, **params)
#     620 res = ZeroLinearOperator() if not diag else 0
#     621 for kern in self.kernels:
# --> 622     next_term = kern(x1, x2, diag=diag, **params)
#     623     if not diag:
#     624         res = res + to_linear_operator(next_term)
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/kernels/kernel.py:539, in Kernel.__call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     536     res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     537 else:
#     538     res = to_linear_operator(
# --> 539         super(Kernel, self).__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params)
#     540     )
#     541 return res
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/module.py:82, in Module.__call__(self, *inputs, **kwargs)
#      81 def __call__(self, *inputs, **kwargs) -> Union[Tensor, Distribution, LinearOperator]:
# ---> 82     outputs = self.forward(*inputs, **kwargs)
#      83     if isinstance(outputs, list):
#      84         return [_validate_module_outputs(output) for output in outputs]
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/kernels/scale_kernel.py:109, in ScaleKernel.forward(self, x1, x2, last_dim_is_batch, diag, **params)
#     108 def forward(self, x1, x2, last_dim_is_batch=False, diag=False, **params):
# --> 109     orig_output = self.base_kernel.forward(x1, x2, diag=diag, last_dim_is_batch=last_dim_is_batch, **params)
#     110     outputscales = self.outputscale
#     111     if last_dim_is_batch:
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/kernels/periodic_kernel.py:141, in PeriodicKernel.forward(self, x1, x2, diag, **params)
#     139 else:
#     140     lengthscale = lengthscale[..., 0, :, None, None]
# --> 141 exp_term = diff.sin().pow(2.0).div(lengthscale).mul(-2.0)
#     143 if not last_dim_is_batch:
#     144     exp_term = exp_term.sum(dim=(-2 if diag else -3))
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 504.00 MiB. GPU 0 has a total capacity of 3.94 GiB of which 191.62 MiB is free. Including non-PyTorch memory, this process has 3.42 GiB memory in use. Of the allocated memory 2.35 GiB is allocated by PyTorch, and 1002.40 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
best_config = perform_gridsearch(kernel_builders, mean_builders, inducing_list, latents_list, epochs_list, lr_list, device, RANDOM_SEED, X_train, y_train, GPModel)

print('Best configuration:')
for k,v in best_config.items():
    print(f'  {k:12s} : {v}')

with open("best_config_coarse_run.pkl", "wb") as f:
    pickle.dump(best_config, f)
# Out:
# Fold 3 | Epoch 250/250:   0%|          | 0/3 [1:28:15<?, ?it/s, rmse=0.208]
#   1/6 in 5295.76s | GP(Constant, RBF) | num_inducing=512, num_latents=12, lr=0.0050, epochs=250 → RMSE=0.2079
# Fold 3 | Epoch 250/250:   0%|          | 0/3 [6:49:00<?, ?it/s, rmse=0.222]
#   2/6 in 24540.16s | GP(Constant, RBF) | num_inducing=1024, num_latents=12, lr=0.0050, epochs=250 → RMSE=0.2255
# Fold 3 | Epoch 250/250:   0%|          | 0/3 [1:33:26<?, ?it/s, rmse=0.201]
#   3/6 in 5606.80s | GP(Constant, Matern32_nu_2_5) | num_inducing=512, num_latents=12, lr=0.0050, epochs=250 → RMSE=0.2006
# Fold 2 | Epoch 250/250:   0%|          | 0/3 [4:42:10<?, ?it/s, rmse=0.221]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 best_config = perform_gridsearch(kernel_builders, mean_builders, inducing_list, latents_list, epochs_list, lr_list, device, RANDOM_SEED, X_train, y_train, GPModel)
#       3 print('Best configuration:')
#       4 for k,v in best_config.items():
#
# File ~/Desktop/ML for RES/utils.py:335, in perform_gridsearch(kernel_builders, mean_builders, inducing_list, latents_list, epochs_list, lr_list, device, RANDOM_SEED, X_train, y_train, GPModel)
#     333 X_tr, X_val = X_train[tr_idx], X_train[val_idx]
#     334 y_tr, y_val = y_train[tr_idx], y_train[val_idx]
# --> 335 rmse = train_and_eval(
#     336     X_tr, y_tr, X_val, y_val,
#     337     kbuilder, mbuilder,
#     338     num_inducing, num_latents,
#     339     lr, epochs, GPModel, device, fold_i=fold_i, outer_pbar=fold_pbar
#     340 )
#     341 fold_pbar.set_postfix(rmse=rmse)
#     342 rmses.append(rmse)
#
# File ~/Desktop/ML for RES/utils.py:308, in train_and_eval(X_tr, y_tr, X_val, y_val, kernel_builder, mean_builder, num_inducing, num_latents, lr, num_epochs, GPModel, device, fold_i, outer_pbar)
#     306 model.eval(); likelihood.eval()
#     307 with torch.no_grad():
# --> 308     pred = likelihood(model(X_val)).mean.cpu()
#     309 rmse = torch.sqrt(((pred - y_val.cpu())**2).mean()).item()
#     310 return rmse
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/models/approximate_gp.py:114, in ApproximateGP.__call__(self, inputs, prior, **kwargs)
#     112 if inputs is not None and inputs.dim() == 1:
#     113     inputs = inputs.unsqueeze(-1)
# --> 114 return self.variational_strategy(inputs, prior=prior, **kwargs)
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/lmc_variational_strategy.py:197, in LMCVariationalStrategy.__call__(self, x, prior, task_indices, **kwargs)
#     163 def __call__(
#     164     self, x: Tensor, prior: bool = False, task_indices: Optional[LongTensor] = None, **kwargs
#     165 ) -> Union[MultitaskMultivariateNormal, MultivariateNormal]:
#     166     r"""
#     167     Computes the variational (or prior) distribution
#     168     :math:`q( \mathbf f \mid \mathbf X)` (or :math:`p( \mathbf f \mid \mathbf X)`).
#    (...)    195         or ~gpytorch.distributions.MultivariateNormal (... x N)
#     196     """
# --> 197     latent_dist = self.base_variational_strategy(x, prior=prior, **kwargs)
#     198     num_batch = len(latent_dist.batch_shape)
#     199     latent_dim = num_batch + self.latent_dim
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/variational_strategy.py:272, in VariationalStrategy.__call__(self, x, prior, **kwargs)
#     269         # Mark that we have updated the variational strategy
#     270         self.updated_strategy.fill_(True)
# --> 272 return super().__call__(x, prior=prior, **kwargs)
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/_variational_strategy.py:347, in _VariationalStrategy.__call__(self, x, prior, **kwargs)
#     345 # Get q(f)
#     346 if isinstance(variational_dist_u, MultivariateNormal):
# --> 347     return super().__call__(
#     348         x,
#     349         inducing_points,
#     350         inducing_values=variational_dist_u.mean,
#     351         variational_inducing_covar=variational_dist_u.lazy_covariance_matrix,
#     352         **kwargs,
#     353     )
#     354 elif isinstance(variational_dist_u, Delta):
#     355     return super().__call__(
#     356         x, inducing_points, inducing_values=variational_dist_u.mean, variational_inducing_covar=None, **kwargs
#     357     )
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/module.py:82, in Module.__call__(self, *inputs, **kwargs)
#      81 def __call__(self, *inputs, **kwargs) -> Union[Tensor, Distribution, LinearOperator]:
# ---> 82     outputs = self.forward(*inputs, **kwargs)
#      83     if isinstance(outputs, list):
#      84         return [_validate_module_outputs(output) for output in outputs]
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/gpytorch/variational/variational_strategy.py:212, in VariationalStrategy.forward(self, x, inducing_points, inducing_values, variational_inducing_covar, **kwargs)
#     210         pass
#     211     L = self._cholesky_factor(induc_induc_covar)
# --> 212 interp_term = L.solve(induc_data_covar.type(_linalg_dtype_cholesky.value())).to(full_inputs.dtype)
#     214 # Compute the mean of q(f)
#     215 # k_XZ K_ZZ^{-1/2} (m - K_ZZ^{-1/2} \mu_Z) + \mu_X
#     216 predictive_mean = (interp_term.transpose(-1, -2) @ inducing_values.unsqueeze(-1)).squeeze(-1) + test_mean
#
# File ~/anaconda3/envs/ML-for-RES/lib/python3.11/site-packages/linear_operator/operators/triangular_linear_operator.py:218, in TriangularLinearOperator.solve(self, right_tensor, left_tensor)
#     215     squeeze = True
#     217 if isinstance(self._tensor, DenseLinearOperator):
# --> 218     res = torch.linalg.solve_triangular(self.to_dense(), right_tensor, upper=self.upper)
#     219 elif isinstance(self._tensor, BatchRepeatLinearOperator):
#     220     res = self._tensor.base_linear_op.solve(right_tensor, left_tensor)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 822.00 MiB. GPU 0 has a total capacity of 3.94 GiB of which 67.25 MiB is free. Including non-PyTorch memory, this process has 3.66 GiB memory in use. Of the allocated memory 1.77 GiB is allocated by PyTorch, and 1.79 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# Second round:
inducing_list = [best_config["num_inducing"]]
latents_list  = [8, 12, 24]
lr_list       = [1e-3, 5e-3, 1e-2]
epochs_list   = [250, 500]
kernel_builders = {best_config["kernel"] : kernel_builders[best_config["kernel"]]}
mean_builders = {best_config["mean"] : mean_builders[best_config["mean"]]}

print(kernel_builders)

best_config = perform_gridsearch(kernel_builders, mean_builders, inducing_list, latents_list, epochs_list, lr_list, device, RANDOM_SEED, X_train, y_train, GPModel)

print('Best configuration:')
for k,v in best_config.items():
    print(f'  {k:12s} : {v}')

with open("best_config.pkl", "wb") as f:
    pickle.dump(best_config, f)

# %% [markdown]
# Validate with 5-Fold-Cross-Validation

# %%
with open("best_config.pkl", "rb") as f:
    best_config = pickle.load(f)
    print(best_config)

# %% [markdown]
# # Train the full model with the best parameters

# %%
num_inducing = best_config['num_inducing']
inducing_points = X_train[:num_inducing].clone()  # shape: (num_inducing, d)

num_tasks = horizon
num_latents = best_config['num_latents'] # Compression dimension, max = num_tasks

mean_kernel = mean_builders[best_config['mean']](num_latents).to(device)
cov_kernel = kernel_builders[best_config['kernel']](num_latents).to(device)
model = GPModel(inducing_points=inducing_points, num_tasks=y_train.shape[1], num_latents=num_latents, mean_module=mean_kernel, covar_module=cov_kernel).to(device)
likelihood = MultitaskGaussianLikelihood(num_tasks=num_tasks).to(device)

# Variational ELBO
mll = gpytorch.mlls.VariationalELBO(likelihood, model, num_data=X_train.size(0))

# Training mode
model.train()
likelihood.train()

optimizer = torch.optim.Adam(
    [{'params': model.parameters()}, {'params': likelihood.parameters()}],
    lr=best_config['lr']
)

# --- Training Loop ---
num_epochs = best_config['epochs']
for epoch in range(num_epochs):
    optimizer.zero_grad()
    output = model(X_train)           # now returns a 24-task MVN
    loss = -mll(output, y_train)      # y_train_tensor shape: (N, 24)
    loss.backward()
    print(f'Epoch {epoch+1}/{num_epochs} - Loss: {loss.item():.3f}')
    optimizer.step()

# %% [markdown]
# # Benchmarking
# See how well the model performs on test data

# %%
# 1) Move everything to CPU & eval mode
device_cpu = torch.device('cpu')
model = model.to(device_cpu).eval()
likelihood = likelihood.to(device_cpu).eval()

X_train = X_train.to(device_cpu)
y_train = y_train.to(device_cpu)
X_test = X_test.to(device_cpu)
y_test = y_test.to(device_cpu)

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    y_hat_likelihood_train = likelihood(model(X_train))
    y_hat_likelihood_test = likelihood(model(X_test))

# %%
step = 1
mean_tr, std_tr = y_hat_train.mean[:,step].detach().numpy(), y_hat_train.stddev[:,step].detach().numpy()
mean_te, std_te = y_hat_test.mean[:,step].detach().numpy(), y_hat_test.stddev[:,step].detach().numpy()

# Train plot
plt.figure(figsize=(12,5))
plt.plot(dates_train, y_train[:,step], 'k*', label='Actual (train)')
plt.plot(dates_train, mean_tr,     'b',  label='Predicted mean')
plt.fill_between(dates_train,
                 (mean_tr-2*std_tr),
                 (mean_tr+2*std_tr),
                 alpha=0.3, label='±2σ')
plt.title('Train set')
plt.legend()
plt.show()

# Test plot
plt.figure(figsize=(12,5))
plt.plot(dates_test, y_test[:,step], 'k', label='Actual (test)')
plt.plot(dates_test, mean_te,      'b',  label='Predicted mean')
plt.fill_between(dates_test,
                 (mean_te-2*std_te),
                 (mean_te+2*std_te),
                 alpha=0.3, label='±2σ')
plt.title('Test set')
plt.legend()
plt.show()

# %%
y_hat_train = y_hat_likelihood_train.mean
rmse_per_horizon_train = torch.sqrt(((y_hat_train - y_train) ** 2).mean(dim=0))  # (24,)

y_hat_test = y_hat_likelihood_test.mean
rmse_per_horizon_test = torch.sqrt(((y_hat_test - y_test) ** 2).mean(dim=0))  # (24,)
